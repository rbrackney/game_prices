# %%
import steamscrape as sts
import numpy as np
import json
import os
import time

# %%
with open("johcar_game_ids.json") as json_file:
    json_data = json.load(json_file)

# %%
appids = []
#json_data[u'games']
          #for k,v in json_data.iteritems():
for item in json_data[u'response'][u'games']:
    appids.append(item[u'appid'])
appids = sorted(appids, reverse=True)

# %%
for a_i in appids:
    fname = 'steam_%d.json' % (a_i)
    fpath = 'steam_jsons/%s' % fname
    if not fname in os.listdir('steam_jsons/'):
        try:
            out_dict, out_hs, error_result = sts.extract_info_games(a_i)
            with open(fpath, 'w') as outfile:
                json.dump(out_dict, outfile)
        except:
            print('problem with %d' % a_i)
        time.sleep(2)
# Out:
# making request
# finished request
# returing steamy soup
# 399580
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 399580
# making request
# problem with 399430
# making request
# finished request
# returing steamy soup
# 399230
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 399230
# making request
# finished request
# returing steamy soup
# 399180
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 399180
# making request
# finished request
# returing steamy soup
# 398920
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 398920
# making request
# finished request
# returing steamy soup
# 398900
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 398900
# making request
# finished request
# returing steamy soup
# 398110
# redirecting
# making request
# problem with 398110
# making request
# finished request
# returing steamy soup
# 397800
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 397800
# making request
# finished request
# returing steamy soup
# 397780
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 397780
# making request
# finished request
# returing steamy soup
# 397620
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 397620
# making request
# finished request
# returing steamy soup
# 397500
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 397500
# making request
# finished request
# returing steamy soup
# 396820
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 396820
# making request
# finished request
# returing steamy soup
# 396730
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 396730
# making request
# finished request
# returing steamy soup
# 396610
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 396610
# making request
# finished request
# returing steamy soup
# 396230
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 396230
# making request
# finished request
# returing steamy soup
# 396160
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 396160
# making request
# finished request
# returing steamy soup
# 395980
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 395980
# making request
# problem with 395930
# making request
# finished request
# returing steamy soup
# 395910
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 395910
# making request
# finished request
# returing steamy soup
# 395480
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 395480
# making request
# finished request
# returing steamy soup
# 395400
# redirecting
# making request
# problem with 395400
# making request
# finished request
# returing steamy soup
# problem with 395380
# making request
# finished request
# returing steamy soup
# 395310
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 395310
# problem with 395310
# making request
# finished request
# returing steamy soup
# 395150
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 395150
# making request
# finished request
# returing steamy soup
# problem with 394770
# making request
# finished request
# returing steamy soup
# 394270
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 394270
# making request
# problem with 394000
# making request
# finished request
# returing steamy soup
# 393970
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 393970
# problem with 393970
# making request
# finished request
# returing steamy soup
# 393660
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 393660
# making request
# finished request
# returing steamy soup
# 393550
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 393550
# making request
# finished request
# returing steamy soup
# 393540
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 393540
# making request
# problem with 393360
# making request
# finished request
# returing steamy soup
# 393350
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 393350
# making request
# finished request
# returing steamy soup
# 392930
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 392930
# making request
# finished request
# returing steamy soup
# problem with 392920
# making request
# finished request
# returing steamy soup
# 392870
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 392870
# making request
# finished request
# returing steamy soup
# 392820
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 392820
# making request
# finished request
# returing steamy soup
# 391950
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 391950
# making request
# finished request
# returing steamy soup
# 391940
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 391940
# making request
# finished request
# returing steamy soup
# 391740
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 391740
# making request
# finished request
# returing steamy soup
# 391660
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 391660
# making request
# finished request
# returing steamy soup
# 391590
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 391590
# making request
# finished request
# returing steamy soup
# 391580
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 391580
# making request
# problem with 391420
# making request
# finished request
# returing steamy soup
# 391410
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 391410
# making request
# finished request
# returing steamy soup
# 391390
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 391390
# making request
# finished request
# returing steamy soup
# 391340
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 391340
# making request
# finished request
# returing steamy soup
# 391260
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 391260
# making request
# finished request
# returing steamy soup
# 391170
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 391170
# making request
# finished request
# returing steamy soup
# 391160
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 391160
# making request
# finished request
# returing steamy soup
# 391070
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 391070
# making request
# finished request
# returing steamy soup
# 391030
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 391030
# making request
# finished request
# returing steamy soup
# 390940
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 390940
# making request
# finished request
# returing steamy soup
# 390910
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 390910
# making request
# finished request
# returing steamy soup
# 390880
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 390880
# making request
# finished request
# returing steamy soup
# 390660
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 390660
# making request
# finished request
# returing steamy soup
# 390570
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 390570
# making request
# finished request
# returing steamy soup
# problem with 390160
# making request
# finished request
# returing steamy soup
# problem with 390070
# making request
# finished request
# returing steamy soup
# 389900
# redirecting
# making request
# problem with 389900
# making request
# finished request
# returing steamy soup
# 389810
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 389810
# making request
# finished request
# returing steamy soup
# 389700
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 389700
# making request
# problem with 389690
# making request
# finished request
# returing steamy soup
# 389460
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 389460
# making request
# finished request
# returing steamy soup
# 389400
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 389400
# making request
# finished request
# returing steamy soup
# 389310
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 389310
# making request
# finished request
# returing steamy soup
# 389270
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 389270
# making request
# finished request
# returing steamy soup
# 389250
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 389250
# making request
# finished request
# returing steamy soup
# 389200
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 389200
# making request
# finished request
# returing steamy soup
# 388870
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 388870
# making request
# finished request
# returing steamy soup
# 388680
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 388680
# making request
# finished request
# returing steamy soup
# 388660
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 388660
# making request
# finished request
# returing steamy soup
# 388620
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 388620
# making request
# finished request
# returing steamy soup
# 388500
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 388500
# making request
# finished request
# returing steamy soup
# 388440
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 388440
# making request
# problem with 388420
# making request
# finished request
# returing steamy soup
# 388390
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 388390
# making request
# finished request
# returing steamy soup
# 388360
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 388360
# making request
# finished request
# returing steamy soup
# 388340
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 388340
# making request
# finished request
# returing steamy soup
# 388300
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 388300
# making request
# finished request
# returing steamy soup
# 388270
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 388270
# making request
# finished request
# returing steamy soup
# 388260
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 388260
# making request
# finished request
# returing steamy soup
# 388160
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 388160
# making request
# problem with 388080
# making request
# problem with 388050
# making request
# finished request
# returing steamy soup
# 388010
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 388010
# making request
# finished request
# returing steamy soup
# 387890
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 387890
# making request
# problem with 387880
# making request
# finished request
# returing steamy soup
# 387860
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 387860
# making request
# finished request
# returing steamy soup
# 387850
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 387850
# making request
# finished request
# returing steamy soup
# 387840
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 387840
# making request
# finished request
# returing steamy soup
# 387810
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 387810
# making request
# finished request
# returing steamy soup
# 387800
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 387800
# making request
# finished request
# returing steamy soup
# 387790
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 387790
# making request
# finished request
# returing steamy soup
# 387780
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 387780
# making request
# problem with 387770
# making request
# finished request
# returing steamy soup
# 387400
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 387400
# making request
# finished request
# returing steamy soup
# 387270
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 387270
# making request
# finished request
# returing steamy soup
# 387070
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 387070
# making request
# finished request
# returing steamy soup
# 386900
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 386900
# making request
# finished request
# returing steamy soup
# 386870
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 386870
# making request
# problem with 386750
# making request
# problem with 386700
# making request
# finished request
# returing steamy soup
# 386630
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 386630
# making request
# finished request
# returing steamy soup
# 386600
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 386600
# making request
# problem with 386540
# making request
# finished request
# returing steamy soup
# 386520
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 386520
# making request
# finished request
# returing steamy soup
# 386420
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 386420
# making request
# finished request
# returing steamy soup
# 386330
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 386330
# making request
# finished request
# returing steamy soup
# 386320
# redirecting
# making request
# problem with 386320
# making request
# finished request
# returing steamy soup
# 386310
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 386310
# making request
# problem with 386270
# making request
# finished request
# returing steamy soup
# 386260
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 386260
# making request
# problem with 386160
# making request
# finished request
# returing steamy soup
# 386140
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 386140
# making request
# problem with 386110
# making request
# finished request
# returing steamy soup
# 386090
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 386090
# making request
# finished request
# returing steamy soup
# 386070
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 386070
# making request
# finished request
# returing steamy soup
# 385980
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 385980
# making request
# finished request
# returing steamy soup
# 385960
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 385960
# making request
# finished request
# returing steamy soup
# 385900
# redirecting
# making request
# finished request
# returing steamy soup
# successfully grabbed 385900
# making request
# problem with 385860

# %%
a_i
